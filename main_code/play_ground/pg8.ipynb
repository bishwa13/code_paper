# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = {
    'Temperature_Type': ['Tavg', 'Tavg', 'Tavg', 'Tavg', 'Tavg'],
    'Region': ['High Mountain', 'High Mountain', 'High Mountain', 'High Mountain', 'High Mountain'],
    'Season': ['Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 'annual'],
    '1962 to 1972': [8.9, 3.2, 4.0, -1.4, 3.7],
    '1972 to 1981': [8.7, 2.9, 3.5, -1.2, 3.5],
    '1982 to 1991': [8.9, 3.6, 4.2, -1.6, 3.7],
    '1992 to 2001': [9.0, 3.4, 4.3, -1.5, 3.9],
    '2002 to 2011': [9.1, 3.5, 4.4, -1.3, 3.8],
    '2012 to 2021': [9.3, 3.8, 4.6, -1.2, 3.9],
    '1962 - 2022': [9.0, 3.4, 4.3, -1.4, 3.7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))  # 2 rows, 3 columns

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of decades to plot
columns_to_plot = ['1962 to 1972', '1972 to 1981', '1982 to 1991', '1992 to 2001', '2002 to 2011', '2012 to 2021']

# Iterate through the columns and axes to create multiple plots
for i, col in enumerate(columns_to_plot):
    axes[i].plot(df['Season'], df[col], marker='o', label=col)
    axes[i].set_title(f"Temperature Trend: {col}")
    axes[i].set_xlabel('Season')
    axes[i].set_ylabel('Temperature')
    axes[i].legend()

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = {
    'Temperature_Type': ['Tavg', 'Tavg', 'Tavg', 'Tavg', 'Tavg'],
    'Region': ['High Mountain', 'High Mountain', 'High Mountain', 'High Mountain', 'High Mountain'],
    'Season': ['Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 'annual'],
    '1962 to 1972': [8.9, 3.2, 4.0, -1.4, 3.7],
    '1972 to 1981': [8.7, 2.9, 3.5, -1.2, 3.5],
    '1982 to 1991': [8.9, 3.6, 4.2, -1.6, 3.7],
    '1992 to 2001': [9.0, 3.4, 4.3, -1.5, 3.9],
    '2002 to 2011': [9.1, 3.5, 4.4, -1.3, 3.8],
    '2012 to 2021': [9.3, 3.8, 4.6, -1.2, 3.9],
    '1962 - 2022': [9.0, 3.4, 4.3, -1.4, 3.7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))  # 2 rows, 3 columns

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of decades to plot
columns_to_plot = ['1962 to 1972', '1972 to 1981', '1982 to 1991', '1992 to 2001', '2002 to 2011', '2012 to 2021']

# Iterate through the columns and axes to create multiple plots
for i, col in enumerate(columns_to_plot):
    axes[i].plot(df['Season'], df[col], marker='o', label=col)
    axes[i].set_title(f"Temperature Trend: {col}")
    axes[i].legend()

# Single shared x-axis and y-axis labels for the entire figure
fig.text(0.5, 0.04, 'Season', ha='center', va='center', fontsize=14)  # Shared x-axis
fig.text(0.04, 0.5, 'Temperature', ha='center', va='center', rotation='vertical', fontsize=14)  # Shared y-axis

# Adjust layout for better spacing
plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])  # Adjust to leave space for the axis labels

# Display the plots
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data setup (replace this with your actual data)
data = {
    'Temperature_Type': ['Tavg'] * 5 + ['Tmin'] * 5,
    'Region': ['High Mountain'] * 5 + ['Tarai'] * 5,
    'Season': ['Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 'Annual'] * 2,
    '1962 to 1971': [0.025195, -0.057980, 0.019327, -0.014643, -0.007025,
                     -0.021290, -0.123951, -0.017326, -0.140717, -0.075821],
    '1972 to 1981': [-0.043017, -0.082583, -0.026063, -0.028205, -0.044967,
                     -0.009577, -0.085332, -0.005208, -0.020097, -0.030053],
    '1982 to 1991': [-0.073591, 0.069807, -0.035453, 0.072848, 0.008402,
                     -0.042281, 0.117157, 0.032979, 0.201696, 0.077388],
    '1992 to 2001': [0.000857, 0.070520, 0.008954, 0.066549, 0.036720,
                     -0.025862, 0.038140, -0.008058, -0.012832, -0.002153],
    '2002 to 2011': [0.002134, 0.029407, 0.104331, 0.032824, 0.042174,
                     -0.019326, 0.053557, 0.077692, 0.002982, 0.028726],
    '2012 to 2021': [0.033521, 0.134570, -0.057446, 0.030839, 0.035371,
                     0.230534, 0.349127, 0.112414, 0.201550, 0.223406],
    '1962 - 2022': [-0.013524, 0.005141, 0.011279, -0.007742, -0.001211,
                    -0.021516, -0.004451, 0.001132, -0.029108, -0.013486]
}

# Create DataFrame
df = pd.DataFrame(data)

# Reshape the DataFrame for better plotting
df_melted = df.melt(id_vars=['Temperature_Type', 'Region', 'Season'],
                     var_name='Decade', value_name='Value')

# Create a heatmap
plt.figure(figsize=(12, 8))
pivot_table = df_melted.pivot_table(index=['Temperature_Type', 'Region', 'Season'], 
                                      columns='Decade', values='Value')

# Set colors
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='coolwarm', center=0)

plt.title('Temperature Trends by Decade')
plt.xlabel('Decade')
plt.ylabel('Temperature Type & Region')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data setup (replace this with your actual data)
data = {
    'Temperature_Type': ['Tavg'] * 5 + ['Tmin'] * 5,
    'Region': ['High Mountain'] * 5 + ['Tarai'] * 5,
    'Season': ['Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 'Annual'] * 2,
    '1962 to 1971': [0.025195, -0.057980, 0.019327, -0.014643, -0.007025,
                     -0.021290, -0.123951, -0.017326, -0.140717, -0.075821],
    '1972 to 1981': [-0.043017, -0.082583, -0.026063, -0.028205, -0.044967,
                     -0.009577, -0.085332, -0.005208, -0.020097, -0.030053],
    '1982 to 1991': [-0.073591, 0.069807, -0.035453, 0.072848, 0.008402,
                     -0.042281, 0.117157, 0.032979, 0.201696, 0.077388],
    '1992 to 2001': [0.000857, 0.070520, 0.008954, 0.066549, 0.036720,
                     -0.025862, 0.038140, -0.008058, -0.012832, -0.002153],
    '2002 to 2011': [0.002134, 0.029407, 0.104331, 0.032824, 0.042174,
                     -0.019326, 0.053557, 0.077692, 0.002982, 0.028726],
    '2012 to 2021': [0.033521, 0.134570, -0.057446, 0.030839, 0.035371,
                     0.230534, 0.349127, 0.112414, 0.201550, 0.223406],
    '1962 - 2022': [-0.013524, 0.005141, 0.011279, -0.007742, -0.001211,
                    -0.021516, -0.004451, 0.001132, -0.029108, -0.013486]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set up the figure and axes
decades = ['1962 to 1971', '1972 to 1981', '1982 to 1991', 
           '1992 to 2001', '2002 to 2011', '2012 to 2021', '1962 - 2022']

# Plotting histograms
plt.figure(figsize=(14, 8))
colors = plt.cm.viridis(range(len(decades)))  # Use a colormap for better visibility

# Loop through each temperature type and region
for i, (temp_type, region) in enumerate(zip(df['Temperature_Type'].unique(), df['Region'].unique())):
    plt.subplot(2, 5, i + 1)  # Create subplots
    temp_data = df[df['Temperature_Type'] == temp_type]
    
    # Plot histogram for each decade
    for j, decade in enumerate(decades):
        plt.hist(temp_data[decade], bins=10, alpha=0.6, color=colors[j], label=decade)

    plt.title(f'{temp_type} - {region}')
    plt.xlabel('Temperature Change')
    plt.ylabel('Frequency')
    plt.legend(title='Decades')
    plt.grid(axis='y')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame with your data
data = {
    'Season': ['Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 
               'Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 
               'Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 
               'Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter', 
               'Monsoon', 'Postmonsoon', 'Premonsoon', 'Winter'],
    'Region': ['High Mountain'] * 4 + ['Hill'] * 4 + ['Middle Mountain'] * 4 + ['Siwalik'] * 4 + ['Tarai'] * 4,
    'Tmax Trend': [-0.0111, 0.0114, 0.0186, 0.0031, 
                   -0.0122, 0.0032, 0.0071, -0.0004, 
                   -0.0038, 0.0233, 0.0125, 0.0317, 
                   -0.0552, -0.0135, -0.0106, -0.0260, 
                   -0.0183, 0.0027, 0.0067, -0.0006],
    'Tmax p-value': [0.1672, 0.1412, 0.0115, 0.7077,
                     0.0338, 0.5873, 0.2333, 0.9422,
                     0.5811, 0.0035, 0.0845, 0.0058,
                     0.0000, 0.0945, 0.1916, 0.0030,
                     0.0005, 0.5809, 0.2577, 0.9121],
    'Tmin Trend': [0.2340, 0.9435, 0.7977, 0.0972,
                   0.0076, 0.8304, 0.1586, 0.0002,
                   0.0019, 0.1022, 0.0103, 0.2583,
                   0.0000, 0.0000, 0.0005, 0.0000,
                   0.0000, 0.4620, 0.8275, 0.0000],
    'Tmin p-value': [0.0160, -0.0011, 0.0040, -0.0177,
                     -0.0128, 0.0011, 0.0074, -0.0207,
                     -0.0234, 0.0128, 0.0164, -0.0088,
                     -0.0592, -0.0443, -0.0421, -0.1013,
                     -0.0215, -0.0045, 0.0011, -0.0280],
    'Tavg Trend': [-0.0135, 0.0051, 0.0113, -0.0073,
                   -0.0125, 0.0021, 0.0072, -0.0106,
                   -0.0136, 0.0181, 0.0144, 0.0114,
                   -0.0572, -0.0289, -0.0264, -0.0637,
                   -0.0199, -0.0009, 0.0039, -0.0143],
    'Tavg p-value': [0.1964, 0.6504, 0.3058, 0.4334,
                     0.0157, 0.6808, 0.1738, 0.0466,
                     0.0062, 0.0035, 0.0084, 0.1407,
                     0.0000, 0.0003, 0.0017, 0.0000,
                     0.0000, 0.8552, 0.4280, 0.0104],
}

df = pd.DataFrame(data)

# Set the index for the heatmap
df_pivot = df.pivot(index="Region", columns="Season", values="Tmax Trend")

# Create the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_pivot, annot=True, cmap='coolwarm', center=0, linewidths=.5)
plt.title('Tmax Trend Heatmap')
plt.xlabel('Season')
plt.ylabel('Region')
plt.show()
